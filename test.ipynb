# %%
import pandas as pd

# %%
playlists = pd.read_csv('Playlists.txt', sep=': ', header=None, engine='python')
playlists
# Out:
#                            0  \
# 0   Top 100 Last 120 days ZA
# 1   Top 100 Last 120 days VN
# 2   Top 100 Last 120 days UZ
# 3   Top 100 Last 120 days US
# 4   Top 100 Last 120 days UA
# 5   Top 100 Last 120 days TW
# 6   Top 100 Last 120 days TR
# 7   Top 100 Last 120 days TH
# 8   Top 100 Last 120 days SK
# 9   Top 100 Last 120 days SG
# 10  Top 100 Last 120 days SE
# 11  Top 100 Last 120 days SA
# 12  Top 100 Last 120 days RO
# 13  Top 100 Last 120 days QA
# 14  Top 100 Last 120 days PT
# 15  Top 100 Last 120 days PL
# 16  Top 100 Last 120 days PK
# 17  Top 100 Last 120 days PH
# 18  Top 100 Last 120 days PE
# 19  Top 100 Last 120 days OM
# 20  Top 100 Last 120 days NZ
# 21  Top 100 Last 120 days NO
# 22  Top 100 Last 120 days NL
# 23  Top 100 Last 120 days NG
# 24  Top 100 Last 120 days MY
# 25  Top 100 Last 120 days MX
# 26  Top 100 Last 120 days MO
# 27  Top 100 Last 120 days MM
# 28  Top 100 Last 120 days MA
# 29  Top 100 Last 120 days LV
# 30  Top 100 Last 120 days LU
# ...
